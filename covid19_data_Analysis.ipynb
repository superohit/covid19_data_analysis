# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules imported successfully!')
# Out:
# Modules imported successfully!

# %%
# load the dataset

corona_dataset_csv = pd.read_csv('Dataset/country_wise_latest.csv')
corona_dataset_csv.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
# check the shape of the dataframe

corona_dataset_csv.shape
# Out:
# (187, 15)

# %%
# delete the useless columns

corona_dataset_csv.drop(['WHO Region'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
# aggregating the rows by the countries

corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan              36263    1269      25198    9796        106
# Albania                   4880     144       2745    1991        117
# Algeria                  27973    1163      18837    7973        616
# Andorra                    907      52        803      52         10
# Angola                     950      41        242     667         18
# Antigua and Barbuda         86       3         65      18          4
# Argentina               167416    3059      72575   91782       4890
# Armenia                  37390     711      26665   10014         73
# Australia                15303     167       9311    5825        368
# Austria                  20558     713      18246    1599         86
#
#                      New deaths  New recovered  Deaths / 100 Cases  \
# Country/Region
# Afghanistan                  10             18                3.50
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 13)

# %%
# Visualizing data related to a country for example China

corona_dataset_aggregated.loc['China'].plot()
#corona_dataset_aggregated.loc['Italy'].plot()
#corona_dataset_aggregated.loc['Spain'].plot()
corona_dataset_aggregated.loc['India'].plot()
plt.legend()

# %%
# calculating a good measure

#corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
# calculating the first derivating of the curve

corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
# find maximum infection rate of India and china

#corona_dataset_aggregated.loc['China'].diff().max()
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 1155334.49

# %%
# minimum infection rate of China and India

#corona_dataset_aggregated.loc['China'].diff().min()
corona_dataset_aggregated.loc['India'].diff().min()
# Out:
# -1446665.0

# %%
# find maximum infection rate for all of the countries

countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# Country/Region
# Afghanistan         36263    1269      25198    9796        106          10
# Albania              4880     144       2745    1991        117           6
# Algeria             27973    1163      18837    7973        616           8
# Andorra               907      52        803      52         10           0
# Angola                950      41        242     667         18           1
#
#                 New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Country/Region
# Afghanistan                18                3.50                  69.49
# Albania                    63                2.95                  56.25
# Algeria                   749                4.16                  67.34
# Andorra                     0                5.73                  88.53
# Angola                      0                4.32                  25.47
#
# ...

# %%
# create a new dataframe with only needed column

corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan               35520.96
# Albania                    4165.75
# Algeria                   23684.83
# Andorra                     877.52
# Angola                      732.06

# %%
# import world happiness dataset

world_happiness_report = pd.read_csv("Dataset/2019.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# shape

world_happiness_report.shape
# Out:
# (156, 9)

# %%
# drop the useless columns

columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
#changing the indices of the dataframe

world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
# lets join the two dataset 

corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan               35520.96
# Albania                    4165.75
# Algeria                   23684.83
# Andorra                     877.52
# Angola                      732.06

# %%
world_happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
# copy and join

data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices  max infection rate
# Country or region
# Finland                                   0.596             7335.25
# Denmark                                   0.592            13448.14
# Norway                                    0.603             9031.09
# Iceland                                   0.591             1838.45
# Netherlands                               0.557            48872.74

# %%
# correlation matrix

data.corr()
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.754906
# Social support                      0.754906        1.000000
# Healthy life expectancy             0.835462        0.719009
# Freedom to make life choices        0.379079        0.447333
# max infection rate                  0.126126        0.082644
#
#                               Healthy life expectancy  \
# GDP per capita                               0.835462
# Social support                               0.719009
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.390395
# max infection rate                           0.083350
#
#                               Freedom to make life choices  max infection rate
# GDP per capita                                    0.379079            0.126126
# Social support                                    0.447333            0.082644
# ...

# %%
# visualising the result

data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices  max infection rate
# Country or region
# Finland                                   0.596             7335.25
# Denmark                                   0.592            13448.14
# Norway                                    0.603             9031.09
# Iceland                                   0.591             1838.45
# Netherlands                               0.557            48872.74

# %%
x = data['GDP per capita']
y = data['max infection rate']
sns.scatterplot(x, np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max infection rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max infection rate'>

# %%
# plot social support and maximum infection rate

x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max infection rate'>

# %%
#  Plotting Healthy life expectancy vs maximum Infection rate

x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %%
# Plotting Freedom to make life choices vs maximum Infection rate

x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max infection rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# c:\users\rohit kumar\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max infection rate'>
